# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## Tình hình tỉ lệ lao động trên 15 tuổi đã qua đào tạo theo từng ngành trong giai đoạn 2011 - 2020 như thế nào?

# %% [markdown]
# ### Đọc và khám phá dữ liệu

# %%
file_name = 'ti_le_lao_dong.json'
with open(file_name, 'r') as myfile:
    if len(myfile.readlines()) != 0:
        myfile.seek(0)
        data = json.load(myfile)

# %%
ti_le_lao_dong_da_qua_dao_tao_theo_nganh = pd.DataFrame(data = np.reshape(data['dataset']['value'], (22, 13)), index = data['dataset']['dimension']['Ngành kinh tế']['category']['label'].values(), columns = data['dataset']['dimension']['Năm']['category']['label'].values())
ti_le_lao_dong_da_qua_dao_tao_theo_nganh = ti_le_lao_dong_da_qua_dao_tao_theo_nganh[ti_le_lao_dong_da_qua_dao_tao_theo_nganh.index != 'TỔNG SỐ']
ti_le_lao_dong_da_qua_dao_tao_theo_nganh
# Out:
#                                                     2009  2010  2011  2012  \
# Nông nghiệp, lâm nghiệp và thủy sản                  3.9   2.4   2.7   3.0
# Khai khoáng                                         41.7  33.7  35.4  43.3
# Công nghiệp chế biến, chế tạo                       14.9  13.5  14.8  16.7
# Sản xuất và phân phối điện, khí đốt, nước nóng,...  53.0  67.3  69.4  77.7
# Cung cấp nước; hoạt động quản lý và xử lý rác t...  37.4  29.6  33.4  32.9
# Xây dựng                                            12.4  12.7  11.7  12.5
# Bán buôn và bán lẻ; sửa chữa ô tô, mô tô, xe má...  13.3  13.7  14.3  14.9
# Vận tải, kho bãi                                    41.2  33.6  36.3  43.4
# Dịch vụ lưu trú và ăn uống                           8.4   8.2   9.1   9.3
# Thông tin và truyền thông                           61.8  70.0  71.9  72.7
# Hoạt động tài chính, ngân hàng và bảo hiểm          67.3  79.3  78.7  78.8
# Hoạt động kinh doanh bất động sản                   29.3  39.4  33.2  30.8
# Hoạt động chuyên môn, khoa học và công nghệ         63.4  65.2  73.1  75.7
# Hoạt động hành chính và dịch vụ hỗ trợ              30.2  31.8  35.7  35.2
# Hoạt động của Đảng Cộng sản, tổ chức chính trị ...  63.0  71.9  71.8  73.8
# Giáo dục và đào tạo                                 78.0  90.8  90.3  91.2
# Y tế và hoạt động trợ giúp xã hội                   76.4  86.9  86.9  86.2
# Nghệ thuật, vui chơi và giải trí                    14.0  16.7  16.4  19.3
# Hoạt động dịch vụ khác                              16.2  13.5  15.3  17.1
# Hoạt động làm thuê các công việc trong các hộ g...   4.2   3.8   2.9   3.6
# Hoạt động của các tổ chức và cơ quan quốc tế        85.4  97.2  82.0  82.1
#
#                                                     2013  2014  2015  2016  \
# Nông nghiệp, lâm nghiệp và thủy sản                  3.5   3.6   4.3   4.1
# Khai khoáng                                         43.2  52.4  49.5  50.7
# Công nghiệp chế biến, chế tạo                       18.4  18.0  18.0  18.5
# Sản xuất và phân phối điện, khí đốt, nước nóng,...  76.3  73.0  75.9  78.7
# Cung cấp nước; hoạt động quản lý và xử lý rác t...  36.0  40.3  45.7  43.1
# Xây dựng                                            14.0  14.0  15.0  13.9
# Bán buôn và bán lẻ; sửa chữa ô tô, mô tô, xe má...  16.6  17.7  21.2  21.6
# Vận tải, kho bãi                                    46.5  44.8  55.6  55.3
# Dịch vụ lưu trú và ăn uống                          10.3  11.8  13.7  13.3
# Thông tin và truyền thông                           78.4  77.8  75.4  80.8
# Hoạt động tài chính, ngân hàng và bảo hiểm          80.2  80.8  82.9  82.9
# Hoạt động kinh doanh bất động sản                   33.5  32.4  42.3  41.4
# Hoạt động chuyên môn, khoa học và công nghệ         73.6  77.0  76.0  81.4
# Hoạt động hành chính và dịch vụ hỗ trợ              39.3  36.4  42.3  43.2
# Hoạt động của Đảng Cộng sản, tổ chức chính trị ...  76.4  76.9  79.7  82.7
# Giáo dục và đào tạo                                 91.0  90.8  91.3  92.0
# Y tế và hoạt động trợ giúp xã hội                   85.4  88.9  89.1  87.8
# Nghệ thuật, vui chơi và giải trí                    19.1  23.1  22.2  25.3
# Hoạt động dịch vụ khác                              23.9  21.7  19.1  20.2
# Hoạt động làm thuê các công việc trong các hộ g...   2.9   2.5   2.7   2.9
# Hoạt động của các tổ chức và cơ quan quốc tế        84.5  90.0  89.8  74.3
#
#                                                     2017  2018  2019   2020  \
# Nông nghiệp, lâm nghiệp và thủy sản                  4.2   4.1   4.0   4.62
# Khai khoáng                                         47.9  51.3  54.0  51.11
# Công nghiệp chế biến, chế tạo                       18.6  17.9  17.7  17.94
# Sản xuất và phân phối điện, khí đốt, nước nóng,...  75.8  72.6  76.4  77.79
# Cung cấp nước; hoạt động quản lý và xử lý rác t...  45.0  37.7  37.5  39.94
# Xây dựng                                            13.7  13.1  14.1  13.86
# Bán buôn và bán lẻ; sửa chữa ô tô, mô tô, xe má...  22.4  22.3  25.1  27.17
# Vận tải, kho bãi                                    58.7  59.0  64.3  66.01
# Dịch vụ lưu trú và ăn uống                          14.6  13.9  13.8  15.99
# Thông tin và truyền thông                           82.9  83.1  86.5  83.49
# Hoạt động tài chính, ngân hàng và bảo hiểm          81.0  85.4  86.0  85.07
# Hoạt động kinh doanh bất động sản                   40.5  56.6  45.4  43.58
# Hoạt động chuyên môn, khoa học và công nghệ         78.4  82.6  80.2  81.93
# Hoạt động hành chính và dịch vụ hỗ trợ              42.0  43.3  43.5  44.10
# Hoạt động của Đảng Cộng sản, tổ chức chính trị ...  82.7  87.9  85.9  85.11
# Giáo dục và đào tạo                                 91.2  91.5  91.2  91.35
# Y tế và hoạt động trợ giúp xã hội                   90.2  91.1  92.2  89.78
# Nghệ thuật, vui chơi và giải trí                    26.3  27.4  25.1  27.82
# Hoạt động dịch vụ khác                              22.5  21.3  20.7  21.07
# Hoạt động làm thuê các công việc trong các hộ g...   3.0   2.6   2.2   2.98
# Hoạt động của các tổ chức và cơ quan quốc tế        88.5  85.5  86.5  81.57
#
#                                                     Sơ bộ 2021
# Nông nghiệp, lâm nghiệp và thủy sản                       4.13
# Khai khoáng                                              63.44
# Công nghiệp chế biến, chế tạo                            23.63
# Sản xuất và phân phối điện, khí đốt, nước nóng,...       79.02
# Cung cấp nước; hoạt động quản lý và xử lý rác t...       39.00
# Xây dựng                                                 14.41
# Bán buôn và bán lẻ; sửa chữa ô tô, mô tô, xe má...       27.80
# Vận tải, kho bãi                                         65.13
# Dịch vụ lưu trú và ăn uống                               14.99
# Thông tin và truyền thông                                86.28
# Hoạt động tài chính, ngân hàng và bảo hiểm               86.79
# Hoạt động kinh doanh bất động sản                        50.82
# Hoạt động chuyên môn, khoa học và công nghệ              84.79
# Hoạt động hành chính và dịch vụ hỗ trợ                   42.80
# Hoạt động của Đảng Cộng sản, tổ chức chính trị ...       88.00
# Giáo dục và đào tạo                                      91.74
# Y tế và hoạt động trợ giúp xã hội                        92.43
# Nghệ thuật, vui chơi và giải trí                         27.05
# Hoạt động dịch vụ khác                                   24.53
# Hoạt động làm thuê các công việc trong các hộ g...        3.76
# Hoạt động của các tổ chức và cơ quan quốc tế             89.34

# %%
shape = ti_le_lao_dong_da_qua_dao_tao_theo_nganh.shape
print("Dữ liệu gồm", shape[0], "dòng và", shape[1], "cột")
# Out:
# Dữ liệu gồm 21 dòng và 13 cột

# %% [markdown]
# Một số thống kê sơ bộ về bộ dữ liệu trên

# %%
ti_le_lao_dong_da_qua_dao_tao_theo_nganh.describe()
# Out:
#             2009       2010       2011       2012       2013       2014  \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean   38.828571  41.961905  42.157143  43.819048  45.380952  46.376190
# std    26.850999  31.772559  30.831487  31.091793  30.809651  31.291387
# min     3.900000   2.400000   2.700000   3.000000   2.900000   2.500000
# 25%    14.000000  13.500000  14.800000  16.700000  18.400000  18.000000
# 50%    37.400000  33.600000  35.400000  35.200000  39.300000  40.300000
# 75%    63.000000  70.000000  71.900000  75.700000  76.400000  77.000000
# max    85.400000  97.200000  90.300000  91.200000  91.000000  90.800000
#
#             2015       2016       2017       2018       2019       2020  \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean   48.176190  48.290476  49.052381  50.009524  50.109524  50.108571
# std    31.083274  30.903558  31.276407  32.018259  32.340670  31.393017
# min     2.700000   2.900000   3.000000   2.600000   2.200000   2.980000
# 25%    19.100000  20.200000  22.400000  21.300000  20.700000  21.070000
# 50%    45.700000  43.200000  45.000000  51.300000  45.400000  44.100000
# 75%    76.000000  80.800000  81.000000  83.100000  85.900000  81.930000
# max    91.300000  92.000000  91.200000  91.500000  92.200000  91.350000
#
#        Sơ bộ 2021
# count   21.000000
# mean    52.375238
# std     32.263899
# min      3.760000
# 25%     24.530000
# 50%     50.820000
# 75%     86.280000
# max     92.430000

# %% [markdown]
# Nhận xét:
# - Theo như thống kê theo 21 ngành nghề, ta có thể thấy tỉ lệ lao động đã qua đào tạo có sự chênh lệch rất lớn giữa các ngành, ngành yêu cầu cao thì có tỉ lệ lao động đã qua đào tạo vượt 80%, ngành yêu cầu thấp thì tỉ lệ chưa tới 10%.
# - Đa phần các ngành có tỉ lệ lao động đã qua đào tạo đạt chưa tới 50% và tỉ lệ này vẫn đang tăng theo từng năm, thể hiện rõ nhất ở các ngành có tỉ lệ nằm ở mức giữa
# - Các nghề có yêu cầu thấp (tỉ lệ dưới 10%) tăng rất chậm, các ngành đạt tỉ lệ cao trên 80% thì hầu như không có sự thay đổi nhiều sau 10 năm do đã đạt mức bão hòa

# %% [markdown]
# ### Sự thay đổi sau 10 năm từ 2011 đến 2020 về Top 5 ngành có tỉ lệ lao động đã qua đào tạo cao nhất.

# %%
temp_2011 = ti_le_lao_dong_da_qua_dao_tao_theo_nganh['2011'].sort_values(ascending = False).head()
temp_2020 = ti_le_lao_dong_da_qua_dao_tao_theo_nganh['2020'].sort_values(ascending = False).head()

# %%
fig, ax = plt.subplots(2, 1, figsize = (10, 4), constrained_layout = True)
temp_2011.plot(ax = ax[0], kind='barh', fontsize = 8)
ax[0].set_title("Top 5 ngành có tỉ lệ lao động qua đào tạo cao nhất năm 2011", fontsize = 12)
for index, value in enumerate(temp_2011.values.tolist()):
    ax[0].text(value + 0.5, index, str(round(value, 1)), color = 'blue')

temp_2020.plot(ax = ax[1], kind='barh', fontsize = 8)
ax[1].set_title("Top 5 ngành có tỉ lệ lao động qua đào tạo cao nhất năm 2020", fontsize = 12)
label = list(temp_2020.index)
label[2] = 'Hoạt động Đảng - chính trị'
ax[1].set_yticks(range(5))
ax[1].set_yticklabels(label)
for index, value in enumerate(temp_2020.values.tolist()):
    ax[1].text(value + 0.5, index, str(round(value, 1)), color = 'blue')

# %% [markdown]
# Nhận xét:
# - Có sự thay đổi trong top 5 ngành có tỉ lệ lao động đã qua đào tạo cao nhất, trong đó vẫn có 3 ngành giữ vững vị trí là "Giáo dục và đào tạo", "Y tế và hoạt động trợ giúp xã hội" và "Hoạt động tài chính, ngân hàng và bảo hiểm".
# - Các hoạt động chính trị và truyền thông được nâng cao chất lượng lao động và cũng cho thấy mức độ quan tâm, quan trọng của các vấn đề này hiện nay, trong thời đại hội nhập và khoa học công nghệ thì các vấn đề về văn hóa, đạo đức luôn cần được phát huy và giữ gìn.
# - Tỉ lệ lao động đã qua đào tạo ở từng thứ hạng năm 2020 đều cao hơn 2011, vì thế mà việc các hoạt động chuyên môn, khoa học bị lọt ra khỏi top 5 không có nghĩa là nó đang thụt lùi hoặc không phát triển, mà chỉ là tốc độ phát triển chậm hơn các ngành trong top 5 mà thôi.

# %% [markdown]
# ### Top 5 ngành có tốc độ tăng trưởng nhanh nhất về tỉ lệ lao động qua đào tạo trong giai đoạn 2011 - 2020

# %%
temp_trend = ti_le_lao_dong_da_qua_dao_tao_theo_nganh['2020'] - ti_le_lao_dong_da_qua_dao_tao_theo_nganh['2011']
temp_trend = temp_trend.sort_values(ascending = False)

# %%
asc_trend = temp_trend.head()
des_trend = temp_trend.tail()

# %%
fig, ax = plt.subplots(2, 1, figsize = (10, 4), constrained_layout = True)

asc_trend.plot(ax = ax[0], kind='barh', fontsize = 8)
ax[0].set_title("Top 5 ngành có tỉ lệ lao động qua đào tạo tăng nhiều nhất", fontsize = 12)
label = list(asc_trend.index)
label[3] = 'Buôn bán và sửa chữa xe'
label[2] = 'Hoạt động Đảng - chính trị'
ax[0].set_yticks(range(5))
ax[0].set_yticklabels(label)
for index, value in enumerate(asc_trend.values.tolist()):
    ax[0].text(value + 0.2, index, str(round(value, 1)), color = 'blue')
    
des_trend.plot(ax = ax[1], kind='barh', fontsize = 8)
ax[1].set_title("Top 5 ngành có tỉ lệ lao động qua đào tạo tăng ít nhất", fontsize = 12)
label = list(des_trend.index)
label[3] = 'Giúp việc, sản xuất sản phẩm và dịch vụ hộ gia đình'
ax[1].set_yticks(range(5))
ax[1].set_yticklabels(label)
for index, value in enumerate(des_trend.values.tolist()):
    if value > 0:
        ax[1].text(value + 0.02, index, str(round(value, 1)), color = 'blue')
    else:
        ax[1].text(value - 0.12, index, str(round(value, 1)), color = 'blue')

# %% [markdown]
# Nhận xét:
# - Trong top 5 ngành có tốc độ tăng trưởng ít nhất vầ tỉ lệ lao động đã qua đào tạo, có 2 ngành "Hoạt động của tổ chức và cơ quan quốc tế" và "Giáo dục và đào tạo" nằm trong top 5 của năm 2011. Như vậy ta có thể thấy 2 ngành này đã đạt mức độ bão hòa, và sẽ tăng trưởng rất chậm hoặc biến động xung quanh chỉ số hiện tại.
# - "Nông nghiệp, lâm nghiệp và thủy sản" với tỉ lệ 2.7% và "Xây dựng" 11.7% vào năm 2011 nằm trong top những ngành có tỉ lệ lao động đã qua đào tạo thấp nhất thì với mức tăng trưởng ít như vậy thật ra cũng đã là nhiều so với con số vốn có lúc ban đầu.

# %% [markdown]
# ## Tình hình số lượng lao động chia theo nghề nghiệp ở nước ta như thế nào?

# %% [markdown]
# ### Đọc và khám phá dữ liệu

# %%
file_name = 'lao_dong_theo_nghe.json'
with open(file_name, 'r') as myfile:
    if len(myfile.readlines()) != 0:
        myfile.seek(0)
        data = json.load(myfile)

# %%
print(data['dataset']['dimension']['Nghề nghiệp']['category']['label'])
# Out:
# {'0': 'TỔNG SỐ', '1': 'Nhà lãnh đạo', '2': 'Chuyên môn kỹ thuật bậc cao', '3': 'Chuyên môn kỹ thuật bậc trung', '4': 'Nhân viên', '5': 'Dịch vụ cá nhân, bảo vệ bán hàng', '6': 'Nghề trong nông, lâm, ngư nghiệp', '7': 'Thợ thủ công và các thợ khác có liên quan', '8': 'Thợ lắp ráp và vận hành máy móc, thiết bị', '9': 'Nghề giản đơn', '10': 'Khác'}

# %%
phan_bo_lao_dong_theo_nghe_nghiep = pd.DataFrame(data = np.reshape(data['dataset']['value'], (11, 13)), index = data['dataset']['dimension']['Nghề nghiệp']['category']['label'].values(), columns = data['dataset']['dimension']['Năm']['category']['label'].values())
phan_bo_lao_dong_theo_nghe_nghiep = phan_bo_lao_dong_theo_nghe_nghiep[phan_bo_lao_dong_theo_nghe_nghiep.index != 'TỔNG SỐ']
phan_bo_lao_dong_theo_nghe_nghiep
# Out:
#                                               2009      2010     2011  \
# Nhà lãnh đạo                                 460.0    469.43   537.95
# Chuyên môn kỹ thuật bậc cao                 2218.9   2524.85  2678.55
# Chuyên môn kỹ thuật bậc trung               1818.3   1764.31  1779.17
# Nhân viên                                    783.2    696.43   766.27
# Dịch vụ cá nhân, bảo vệ bán hàng            7432.0   7144.78   7538.1
# Nghề trong nông, lâm, ngư nghiệp            7051.3   7583.55  7085.96
# Thợ thủ công và các thợ khác có liên quan   5983.3   6198.31  6094.47
# Thợ lắp ráp và vận hành máy móc, thiết bị   3188.1    3464.4  3529.13
# Nghề giản đơn                              18808.6  19169.96  20430.4
# Khác                                          None    108.39   107.21
#
#                                                2012     2013     2014  \
# Nhà lãnh đạo                                 531.53    553.7    578.9
# Chuyên môn kỹ thuật bậc cao                 2810.18   2982.1   3261.6
# Chuyên môn kỹ thuật bậc trung               1749.21   1710.9   1655.5
# Nhân viên                                    841.95    887.0    923.0
# Dịch vụ cá nhân, bảo vệ bán hàng            8198.82   8482.1   8527.3
# Nghề trong nông, lâm, ngư nghiệp            6570.52   6283.6   6396.9
# Thợ thủ công và các thợ khác có liên quan   6105.99   6335.4   6374.4
# Thợ lắp ráp và vận hành máy móc, thiết bị   3757.74   3678.4   3945.8
# Nghề giản đơn                              21019.34  21466.5  21229.9
# Khác                                         105.21    128.1    137.3
#
#                                               2015     2016     2017     2018  \
# Nhà lãnh đạo                                 574.1    551.9    606.2    619.4
# Chuyên môn kỹ thuật bậc cao                 3498.1   3637.0   3800.8   3813.0
# Chuyên môn kỹ thuật bậc trung               1687.9   1642.8   1757.4   1863.7
# Nhân viên                                    982.8   1003.0    978.3   1085.9
# Dịch vụ cá nhân, bảo vệ bán hàng            8813.7   8838.6   8928.0   9608.2
# Nghề trong nông, lâm, ngư nghiệp            5396.5   5412.4   5158.9   4984.6
# Thợ thủ công và các thợ khác có liên quan   6442.5   6923.1   7163.2   7478.9
# Thợ lắp ráp và vận hành máy móc, thiết bị   4605.5   5033.3   5275.0   5494.2
# Nghề giản đơn                              20986.3  20178.6  19908.3  19228.4
# Khác                                         123.0    124.7    132.5    106.1
#
#                                               2019      2020 Sơ bộ 2021
# Nhà lãnh đạo                                 521.6    554.21      478.5
# Chuyên môn kỹ thuật bậc cao                 4279.0   4285.91     3595.7
# Chuyên môn kỹ thuật bậc trung               1854.5    1732.6     1634.7
# Nhân viên                                   1071.5   1016.34     1126.7
# Dịch vụ cá nhân, bảo vệ bán hàng            9526.4   9637.68     9300.7
# Nghề trong nông, lâm, ngư nghiệp            4008.1   3938.19     5993.7
# Thợ thủ công và các thợ khác có liên quan   7843.2   7353.86     7139.9
# Thợ lắp ráp và vận hành máy móc, thiết bị   6603.6   7100.37     6928.5
# Nghề giản đơn                              18837.7  17884.14    12628.9
# Khác                                         113.6    106.28      244.8

# %%
shape = phan_bo_lao_dong_theo_nghe_nghiep.shape
print("Dữ liệu gồm", shape[0], "dòng và", shape[1], "cột")
# Out:
# Dữ liệu gồm 10 dòng và 13 cột

# %%
phan_bo_lao_dong_theo_nghe_nghiep.describe()
# Out:
#           2009      2010    2011    2012   2013     2014     2015     2016  \
# count      9.0     10.00   10.00   10.00   10.0     10.0     10.0     10.0
# unique     9.0     10.00   10.00   10.00   10.0     10.0     10.0     10.0
# top     1818.3  19169.96  107.21  105.21  128.1  21229.9  20986.3  20178.6
# freq       1.0      1.00    1.00    1.00    1.0      1.0      1.0      1.0
#
#           2017    2018   2019      2020  Sơ bộ 2021
# count     10.0    10.0   10.0     10.00        10.0
# unique    10.0    10.0   10.0     10.00        10.0
# top     8928.0  4984.6  113.6  17884.14      6928.5
# freq       1.0     1.0    1.0      1.00         1.0

# %% [markdown]
# Nhận xét:
# - Có sự cách biệt lớn về số lượng lao động giữa các ngành nghề với nghề có số lượng lớn lên đến hơn 18000, nghề có ít lao động chỉ khoảng 100 người.
# - Nghề có ít lao động có sự biến động ít giữa các năm và trong cả giai đoạn 2011 - 2020, nghề có số lao động cao nhất thì giảm dần dù cho tổng số lượng lao động đang ngày càng tăng, như vậy ta có thể kết luận lao động của nhóm này đang chuyển dịch sang những nhóm khác.

# %% [markdown]
# ### Cơ cấu lao động theo nghề nghiệp trong 2 năm 2011 và 2020

# %%
fig, ax = plt.subplots(1, 2, figsize = (8, 8))

ax[0].pie(phan_bo_lao_dong_theo_nghe_nghiep['2011'], autopct='%.2f%%', labels = None, pctdistance=1.2)
ax[0].set_title('2011', y = -0.05)

ax[1].pie(phan_bo_lao_dong_theo_nghe_nghiep['2020'], autopct='%.2f%%', labels = None, pctdistance=1.2)
ax[1].set_title('2020', y = -0.05)

fig.legend(labels = phan_bo_lao_dong_theo_nghe_nghiep.index, loc="right", bbox_to_anchor=(1.4, 0.5))
fig.suptitle('Biểu đồ tỉ trọng theo vị trí nghề nghiệp', y = 0.72)
# Out:
# Text(0.5, 0.72, 'Biểu đồ tỉ trọng theo vị trí nghề nghiệp')

# %% [markdown]
# Nhận xét:
# - "Nhà lãnh đạo" có số lượng lao động ổn định.
# - Giảm ở nhóm "Nghề giản đơn", "Nghề nông, lâm, ngư nghiệp"
# - Tăng ở nhóm "Thợ lắp ráp và vận hành máy móc, thiết bị", "Chuyên môn kỹ thuật bậc cao", "Dịch vụ, bảo vệ, bán hàng" và "Thợ thủ công".
# - Cơ cấu lao động ở các nhóm yêu cầu ít tri thức, kỹ thuật hoặc kiến thức chuyên môn đang dần chuyển dịch sang nhóm có chuyên môn cao hơn. Các nhóm ngành này do có sự tác động của công nghệ, thiết bị, máy móc hiện đại thay thế cho sức lao động của con người nên nhu cầu cũng giảm đi.
# - Cơ cấu lao động đang dần chuyển dịch sang các ngành yêu cầu chuyên môn cao hoặc không thể thực hiện bằng máy móc (thợ thủ công).

# %% [markdown]
# ### Tốc độ tăng trưởng theo từng nghề trong giai đoạn 2011 - 2020

# %%
temp_trend = (phan_bo_lao_dong_theo_nghe_nghiep['2020'] - phan_bo_lao_dong_theo_nghe_nghiep['2011']) / phan_bo_lao_dong_theo_nghe_nghiep['2011'] * 100
temp_trend = temp_trend.sort_values(ascending = False)
asc_trend = temp_trend.head()
des_trend = temp_trend.tail()

# %%
fig, ax = plt.subplots(2, 1, figsize = (10, 4), constrained_layout = True)

asc_trend.plot(ax = ax[0], kind='barh', fontsize = 10)
ax[0].set_title("Top 5 nghề có tốc độ tăng trưởng cao nhất về tỉ lệ lao động", fontsize = 12)
for index, value in enumerate(asc_trend.values.tolist()):
    ax[0].text(value + 1, index, str(round(value, 1)), color = 'blue')
    
des_trend.plot(ax = ax[1], kind='barh', fontsize = 10)
ax[1].set_title("Top 5 nghề có tốc độ tăng trưởng thấp nhất về tỉ lệ lao động", fontsize = 12)
for index, value in enumerate(des_trend.values.tolist()):
    if value > 0:
        ax[1].text(value + 0.5, index, str(round(value, 1)), color = 'blue')
    else:
        ax[1].text(value - 2.8, index, str(round(value, 1)), color = 'blue')

# %% [markdown]
# Nhận xét:
# - Nhu cầu lao động tăng cao ở các ngành yêu cầu ký thuật, kiến thức chuyên môn cao hoặc máy móc không thể thay thế con người, nổi bật nhất là nhóm "Thợ lắp ráp và vận hành" tăng gấp đôi về số lượng trong giai đoạn này.
# - Các nhóm ngành bị thay thế hoặc được trợ giúp cao từ quá trình công nghiệp hóa, hiện đại hóa có sự giảm mạnh điển hình là "Nông, lâm, ngư nghiệp" giảm một nửa và "Nghề giản đơn" giảm 1/10 trên tổng số dù cho tổng số lượng người lao động trong nền kinh tế vẫn đang ngày một tăng.
